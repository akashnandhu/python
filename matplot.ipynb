# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pylab as plt

# %%
x=[1,2,3,4,5,6]
y=[34,12,27,49,76,87]
plt.plot(x,y)
plt.show()

# %%
import pandas as pd
df=pd.read_csv("student_marks.csv")
df
# Out:
#   Unnamed: 0 Gender         DOB  Maths  Physics  Chemistry  English  Biology  \
# 0       John      M  05-04-1988     55       45         56       87       21
# 1     Suresh      M  04-05-1987     75       96         78       64       90
# 2     Ramesh      M  25-05-1989     25       54         89       76       95
# 3    Jessica      F  12-08-1990     78       96         86       63       54
# 4   Jennifer      F  02-09-1989     58       96         78       46       96
# 5       Annu      F  05-04-1988     45       87         52       89       55
# 6      pooja      F  04-05-1987     55       64         61       58       75
# 7     Ritesh      M  25-05-1989     54       76         87       56       25
# 8      Farha      F  12-08-1990     55       63         89       75       78
# 9     Mukesh      M  02-09-1989     96       46         77       83       58
#
#    Economics  History  Civics
# 0         52       89      65
# 1         61       58       2
# ...

# %%
plt.plot(df["Physics"],df["Chemistry"])
plt.show()

# %%
plt.plot(df["Physics"],df["Chemistry"],mec="k",mfc="m",marker="o",linestyle="-.",color="#033128c3")
var=plt.gca()
var.spines["top"].set_visible(False)
var.spines["right"].set_visible(False)
plt.show()

# %%
import matplotlib.pylab as plt
import pandas as pd
import numpy as np
x1=np.array([1,10,8,2,5])
x2=np.array([1,3,4,7,11])
plt.plot(x1,x2,mec="k",mfc="r",marker="o",linestyle="--",color="#56016ec3")
plt.show()
df=pd.DataFrame({
    "name":[1,2,3,4,5],
    "number":[3,5,6,8,9]
})
plt.plot(df["name"],df["number"],mec="k",mfc="c",marker="o",linestyle="--",color="#169a2cc3")
plt.show()

# %%
import matplotlib.pylab as plt
x=[11,13,19,24,15]
y=[26,17,18,29,23]
plt.figure(figsize=(10,5))
plt.title("Graphz")
plt.subplot(4,4,1)
f1={"family":"Arial","color":"r","size":10}
f2={"family":"Arial","color":"m","size":10}
plt.plot(x,mec="k",mfc="c",ms=7,marker="o",linestyle="-.",color="#A60707",label="x_point")
plt.plot(y,mec="k",mfc="c",ms=7,marker="o",linestyle="-.",color="#062485",label="y_point")
plt.xlabel("x_values",fontdict=f1)
plt.ylabel("y_values",fontdict=f2)
plt.legend(loc="upper left",shadow=True,title="Indication",title_fontsize=8,fontsize=7)
plt.subplot(4,4,2)
x=[29,21,20,19,17]
y=[22,23,24,25,26]
f1={"family":"Arial","color":"r","size":10}
f2={"family":"Arial","color":"m","size":10}
plt.plot(x,mec="k",mfc="c",ms=7,marker="o",linestyle="-.",color="#A60707",label="x_point")
plt.plot(y,mec="k",mfc="c",ms=7,marker="o",linestyle="-.",color="#062485",label="y_point")
plt.xlabel("x_values",fontdict=f1)
plt.ylabel("y_values",fontdict=f2)
plt.legend(loc="upper left",shadow=True,title="Indication",title_fontsize=8,fontsize=7)
plt.subplot(4,4,3)
x=[13,14,15,16,17]
y=[10,11,12,14,15]
f1={"family":"Arial","color":"r","size":10}
f2={"family":"Arial","color":"m","size":10}
plt.plot(x,mec="k",mfc="c",ms=7,marker="o",linestyle="-.",color="#A60707",label="x_point")
plt.plot(y,mec="k",mfc="c",ms=7,marker="o",linestyle="-.",color="#062485",label="y_point")
plt.xlabel("x_values",fontdict=f1)
plt.ylabel("y_values",fontdict=f2)
plt.legend(loc="upper left",shadow=True,title="Indication",title_fontsize=8,fontsize=7)
plt.subplot(4,4,4)
x=[9,8,5,6,3]
y=[8,7,6,5,9]
f1={"family":"Arial","color":"r","size":10}
f2={"family":"Arial","color":"m","size":10}
plt.plot(x,mec="k",mfc="c",ms=7,marker="o",linestyle="-.",color="#A60707",label="x_point")
plt.plot(y,mec="k",mfc="c",ms=7,marker="o",linestyle="-.",color="#062485",label="y_point")
plt.xlabel("x_values",fontdict=f1)
plt.ylabel("y_values",fontdict=f2)
plt.legend(loc="upper left",shadow=True,title="Indication",title_fontsize=8,fontsize=7)
plt.subplot(4,4,5)
x=[9,7,6,5,4]
y=[3,4,2,1,2]
f1={"family":"Arial","color":"r","size":10}
f2={"family":"Arial","color":"m","size":10}
plt.plot(x,mec="k",mfc="c",ms=7,marker="o",linestyle="-.",color="#A60707",label="x_point")
plt.plot(y,mec="k",mfc="c",ms=7,marker="o",linestyle="-.",color="#062485",label="y_point")
plt.xlabel("x_values",fontdict=f1)
plt.ylabel("y_values",fontdict=f2)
plt.legend(loc="upper left",shadow=True,title="Indication",title_fontsize=8,fontsize=7)
plt.subplot(4,4,6)
x=[9,6,7,5,4]
y=[1,9,2,8,3]
f1={"family":"Arial","color":"r","size":10}
f2={"family":"Arial","color":"m","size":10}
plt.plot(x,mec="k",mfc="c",ms=7,marker="o",linestyle="-.",color="#A60707",label="x_point")
plt.plot(y,mec="k",mfc="c",ms=7,marker="o",linestyle="-.",color="#062485",label="y_point")
plt.xlabel("x_values",fontdict=f1)
plt.ylabel("y_values",fontdict=f2)
plt.legend(loc="upper left",shadow=True,title="Indication",title_fontsize=8,fontsize=7)
plt.subplot(4,4,7)
x=[1,3,5,7,9]
y=[2,4,6,8,10]
f1={"family":"Arial","color":"r","size":10}
f2={"family":"Arial","color":"m","size":10}
plt.plot(x,mec="k",mfc="c",ms=7,marker="o",linestyle="-.",color="#A60707",label="x_point")
plt.plot(y,mec="k",mfc="c",ms=7,marker="o",linestyle="-.",color="#062485",label="y_point")
plt.xlabel("x_values",fontdict=f1)
plt.ylabel("y_values",fontdict=f2)
plt.legend(loc="upper left",shadow=True,title="Indication",title_fontsize=8,fontsize=7)
plt.subplot(4,4,8)
x=[10,11,12,13,14]
y=[15,16,17,18,19]
f1={"family":"Arial","color":"r","size":10}
f2={"family":"Arial","color":"m","size":10}
plt.plot(x,mec="k",mfc="c",ms=7,marker="o",linestyle="-.",color="#A60707",label="x_point")
plt.plot(y,mec="k",mfc="c",ms=7,marker="o",linestyle="-.",color="#062485",label="y_point")
plt.xlabel("x_values",fontdict=f1)
plt.ylabel("y_values",fontdict=f2)
plt.legend(loc="upper left",shadow=True,title="Indication",title_fontsize=8,fontsize=7)
plt.subplot(4,4,9)
x=[10,11,12,13,14]
y=[15,16,17,18,19]
f1={"family":"Arial","color":"r","size":10}
f2={"family":"Arial","color":"m","size":10}
plt.plot(x,mec="k",mfc="c",ms=7,marker="o",linestyle="-.",color="#A60707",label="x_point")
plt.plot(y,mec="k",mfc="c",ms=7,marker="o",linestyle="-.",color="#062485",label="y_point")
plt.xlabel("x_values",fontdict=f1)
plt.ylabel("y_values",fontdict=f2)
plt.legend(loc="upper left",shadow=True,title="Indication",title_fontsize=8,fontsize=7)
plt.subplot(4,4,10)
x=[10,11,12,13,14]
y=[15,16,17,18,19]
f1={"family":"Arial","color":"r","size":10}
f2={"family":"Arial","color":"m","size":10}
plt.plot(x,mec="k",mfc="c",ms=7,marker="o",linestyle="-.",color="#A60707",label="x_point")
plt.plot(y,mec="k",mfc="c",ms=7,marker="o",linestyle="-.",color="#062485",label="y_point")
plt.xlabel("x_values",fontdict=f1)
plt.ylabel("y_values",fontdict=f2)
plt.legend(loc="upper left",shadow=True,title="Indication",title_fontsize=8,fontsize=7)
plt.subplot(4,4,11)
x=[10,11,12,13,14]
y=[15,16,17,18,19]
f1={"family":"Arial","color":"r","size":10}
f2={"family":"Arial","color":"m","size":10}
plt.plot(x,mec="k",mfc="c",ms=7,marker="o",linestyle="-.",color="#A60707",label="x_point")
plt.plot(y,mec="k",mfc="c",ms=7,marker="o",linestyle="-.",color="#062485",label="y_point")
plt.xlabel("x_values",fontdict=f1)
plt.ylabel("y_values",fontdict=f2)
plt.legend(loc="upper left",shadow=True,title="Indication",title_fontsize=8,fontsize=7)
plt.subplot(4,4,12)
x=[10,11,12,13,14]
y=[15,16,17,18,19]
f1={"family":"Arial","color":"r","size":10}
f2={"family":"Arial","color":"m","size":10}
plt.plot(x,mec="k",mfc="c",ms=7,marker="o",linestyle="-.",color="#A60707",label="x_point")
plt.plot(y,mec="k",mfc="c",ms=7,marker="o",linestyle="-.",color="#062485",label="y_point")
plt.xlabel("x_values",fontdict=f1)
plt.ylabel("y_values",fontdict=f2)
plt.legend(loc="upper left",shadow=True,title="Indication",title_fontsize=8,fontsize=7)
plt.subplot(4,4,13)
x=[10,11,12,13,14]
y=[15,16,17,18,19]
f1={"family":"Arial","color":"r","size":10}
f2={"family":"Arial","color":"m","size":10}
plt.plot(x,mec="k",mfc="c",ms=7,marker="o",linestyle="-.",color="#A60707",label="x_point")
plt.plot(y,mec="k",mfc="c",ms=7,marker="o",linestyle="-.",color="#062485",label="y_point")
plt.xlabel("x_values",fontdict=f1)
plt.ylabel("y_values",fontdict=f2)
plt.legend(loc="upper left",shadow=True,title="Indication",title_fontsize=8,fontsize=7)
plt.subplot(4,4,14)
x=[11,13,19,24,15]
y=[26,17,18,29,23]
f1={"family":"Arial","color":"r","size":10}
f2={"family":"Arial","color":"m","size":10}
plt.plot(x,mec="k",mfc="c",ms=7,marker="o",linestyle="-.",color="#A60707",label="x_point")
plt.plot(y,mec="k",mfc="c",ms=7,marker="o",linestyle="-.",color="#062485",label="y_point")
plt.xlabel("x_values",fontdict=f1)
plt.ylabel("y_values",fontdict=f2)
plt.legend(loc="upper left",shadow=True,title="Indication",title_fontsize=8,fontsize=7)
plt.subplot(4,4,15)
x=[11,13,19,24,15]
y=[26,17,18,29,23]
f1={"family":"Arial","color":"r","size":10}
f2={"family":"Arial","color":"m","size":10}
plt.plot(x,mec="k",mfc="c",ms=7,marker="o",linestyle="-.",color="#A60707",label="x_point")
plt.plot(y,mec="k",mfc="c",ms=7,marker="o",linestyle="-.",color="#062485",label="y_point")
plt.xlabel("x_values",fontdict=f1)
plt.ylabel("y_values",fontdict=f2)
plt.legend(loc="upper left",shadow=True,title="Indication",title_fontsize=8,fontsize=7)
plt.subplot(4,4,16)
x=[11,13,19,24,15]
y=[26,17,18,29,23]
f1={"family":"Arial","color":"r","size":10}
f2={"family":"Arial","color":"m","size":10}
plt.plot(x,mec="k",mfc="c",ms=7,marker="o",linestyle="-.",color="#A60707",label="x_point")
plt.plot(y,mec="k",mfc="c",ms=7,marker="o",linestyle="-.",color="#062485",label="y_point")
plt.xlabel("x_values",fontdict=f1)
plt.ylabel("y_values",fontdict=f2)
plt.legend(loc="upper left",shadow=True,title="Indication",title_fontsize=8,fontsize=7)
var=plt.gca()
var.spines["top"].set_visible(False)
var.spines["right"].set_visible(False)
plt.show()

# %%
import matplotlib.pylab as plt
x=[1,2,3,4,5,6,14,12,18,17,12,11]
y=[3,2,4,5,6,7,11,13,12,13,14,15]
# a=["r","k","b","m","b","m"]
s=[150,155,158,159,514,512]
plt.scatter(x,y,color="k",alpha=0.5,s=80,marker="^")    
x=[6,10,8,4,1,9,11,14,16,19,17,12]
y=[7,6,4,5,2,10,19,17,16,12,21,20]
# a=["r","k","b","m","b","m"]
plt.scatter(x,y,color="r",alpha=0.5,s=80,marker="*")  
c=plt.colorbar(orientation="vertical",shrink=1,extend="both")  
c.set_label(label="Colorbar",size=15)
c.set_ticks([0,5,10,8])
c.set_ticklabels(["0 Normal","5 Medium"," Average","Max"])
plt.show()

# %%
import pandas as pd
df=pd.read_csv("profit_and_loss.csv")
for i in df["Profit/Loss"]:
    if i<-1:
        var+=i
        print(var)
# plt.bar(df["Year"],df["Profit/Loss"])
# plt.bar(df.var)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 5
#       3 for i in df["Profit/Loss"]:
#       4     if i<-1:
# ----> 5         var+=i
#       6         print(var)
#       7 # plt.bar(df["Year"],df["Profit/Loss"])
#       8 # plt.bar(df.var)
#
# TypeError: unsupported operand type(s) for +=: 'Axes' and 'int'

# %%
import pandas as pd
df=pd.read_csv("profit_and_loss.csv")
plt.grid(axis="x",linestyle="-.")
plt.grid(axis="y",linestyle="-.")
plt.grid(axis="both",linestyle="-.")
plt.grid(which="minor",linestyle=":",c="k",zorder=1)
plt.grid(which="major",linestyle="--",color="grey",lw=1)
plt.minorticks_on()
plt.barh(x,y,zorder=2)   #horizontal
df
plt.show()

# %%
import matplotlib.pylab as plt
import numpy as np
years=(2021,2022,2023,2024,2025)
x=(11,12,10,13,14)

y=(10,21,23,13,12)
z=(1,2,3,4,5)
plt.title("Layout",c="k",fontsize=15)
plt.bar(years,x,width=0.4,color="r",zorder=2)
plt.bar(years,y,width=0.4,bottom=x,color="y",zorder=2)
plt.bar(years,z,width=0.4,color="g",zorder=2)


plt.grid(which="minor",linestyle="-.",c="b",zorder=1)
plt.grid(which="major",linestyle="-.",linewidth=0.4,c="k")
plt.minorticks_on()

plt.ylim=(0,20)
plt.show()

# %%
import matplotlib.pylab as plt
men=(22,30,35,35,26)
women=(25,32,30,35,29)
plt.bar(men,women)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[48], line 4
#       2 men=(22,30,35,35,26)
#       3 women=(25,32,30,35,29)
# ----> 4 plt.bar(men,wom)
#       5 plt.show()
#
# NameError: name 'wom' is not defined

# %%
import matplotlib.pylab as plt
languages=['Java','Python','Php','Js','C#','C++']
popularity=[22.2,17.6,8.8,8,7.7,6.7]
plt.barh(languages,popularity,color="g",zorder=2)
plt.title("Popularity of Programming Languages")
plt.xlabel("popularity")
plt.ylabel("languages")
plt.grid(which="minor",linestyle="--",color="k",alpha=0.4,zorder=1)
plt.grid(which="major",linestyle=":",color="r",linewidth=1)
plt.minorticks_on()
plt.show()

# %%
import matplotlib.pylab as plt
languages=['Java','Python','Php','Js','C#','C++']
popularity=[22.2,17.6,8.8,8,7.7,6.7]
plt.bar(languages,popularity,color="b",zorder=2,edgecolor="k")
plt.title("Popularity of Programming Languages")
plt.xlabel("popularity")
plt.ylabel("languages")
plt.grid(which="minor",linestyle="--",color="k",alpha=0.4,zorder=1)
plt.grid(which="major",linestyle=":",color="r",linewidth=1)
plt.minorticks_on()
plt.show()

# %%
import matplotlib.pylab as plt
languages=['Java','Python','Php','Js','C#','C++']
popularity=[22.2,17.6,8.8,8,7.7,6.7]
plt.bar(languages,popularity,color="c",zorder=2,edgecolor="k")
plt.title("Popularity of Programming Languages")
plt.xlabel("popularity")
plt.ylabel("languages")
plt.grid(which="minor",linestyle="--",color="k",alpha=0.4,zorder=1)
plt.grid(which="major",linestyle=":",color="r",linewidth=1)
plt.minorticks_on()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
df=pd.read_csv("profit_and_loss.csv")
df
plt.bar(df["Year"],df["Profit/Loss"],color=c,zorder=2,edgecolor="k")
c=[]
for i in df["Profit/Loss"]:
    if i<0:
        c.append("r")
    else:
        c.append("g")
plt.grid(which="minor",axis="both",linestyle="--",color="c",alpha=0.4,zorder=1)
plt.minorticks_on()
plt.grid(which="major",axis="both",linestyle="-.",color="k",alpha=0.4,zorder=1,lw=0.9)
plt.show()

# %%
y=np.array([3,8,1,10])
x=[0,0,0.3,0]
c=["r","b","c","m"]
plt.pie(y,shadow=True,colors=c,labels=["anju","nandana","gopika","akash"],explode=x,autopct="%.2f%%")
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy  as np
data=np.random.randn(100)
plt.hist(data,bins=30,color="r",edgecolor="k")
plt.xlabel("Values")
plt.ylabel("Frequency")
plt.title("Histogram Example")
plt.show()

# %%
df=pd.read_csv("student_marks.csv")
ax=plt.axes(projection="3d")
ax.plot3D(df["Maths"],df["Physics"])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt
import numpy  as np
fig=plt.figure()
ax=fig.add_subplot(111,projection="3d")
x=np.array([1,2,3,4])
y=np.array([3,4,5,6])
z=np.array(range(0,4))  #base of bar
dx=dy=0.5
dz=np.array([10,20,15,25])
ax.bar3d(x,y,z,dx,dy,dz,color="r")
ax.set_xlabel("Years")
ax.set_ylabel("Y")
ax.set_zlabel("profit_loss")
ax.set_title("3D bar chart")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy  as np
x=(['Java','Python','Php','Js','C#','C++'])
y=([22.2,17.6,8.8,8,7.7,6.7])
m=["#0e0836","#4b0a0a","#4715E9","#4c5b0c","#DA9007","#35d709"]
plt.bar(x,y,color=m,zorder=3,label="Growth point",)
plt.title("Growth of Programming Languages",size=18,color="k")
f1={"family":"Arial","color":"k","size":15}
f2={"family":"Arial","color":"m","size":14}
plt.xlabel("LANGUAGES",color="k",fontdict=f1)
plt.ylabel("GROWTH",color="k",fontdict=f2)
plt.grid(which="minor",axis="both",linestyle="--",lw=0.5,color="#0e0836",zorder=1)
plt.grid(which="major",axis="both",linestyle="-.",lw=0.6,color="#111111",zorder=2)
plt.minorticks_on()
plt.legend(loc="upper right",shadow=True,title="IDENTATION",title_fontsize=8,fontsize=7)
plt.tight_layout()
plt.show()
