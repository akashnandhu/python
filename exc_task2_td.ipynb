# %% [markdown]
# # MPG Cars

# %% [markdown]
# ### Introduction:
#
# The following exercise utilizes data from [UC Irvine Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Auto+MPG)
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the first dataset [cars1](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/05_Merge/Auto_MPG/cars1.csv) and [cars2](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/05_Merge/Auto_MPG/cars2.csv).

# %%
df=pd.read_csv("cars1.csv")
df
de=pd.read_csv("cars2.csv")
de
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    33.0          4            91         53    1795          17.4     76
# 1    20.0          6           225        100    3651          17.7     76
# 2    18.0          6           250         78    3574          21.0     76
# 3    18.5          6           250        110    3645          16.2     76
# 4    17.5          6           258         95    3193          17.8     76
# ..    ...        ...           ...        ...     ...           ...    ...
# 195  27.0          4           140         86    2790          15.6     82
# 196  44.0          4            97         52    2130          24.6     82
# 197  32.0          4           135         84    2295          11.6     82
# 198  28.0          4           120         79    2625          18.6     82
# 199  31.0          4           119         82    2720          19.4     82
#
#      origin                 car
# 0         3         honda civic
# ...

# %% [markdown]
#    ### Step 3. Assign each to a variable called cars1 and cars2

# %%
car1=pd.read_csv("cars1.csv")
car1
car2=pd.read_csv("cars2.csv")
car2
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    18.0          8           307        130    3504          12.0     70
# 1    15.0          8           350        165    3693          11.5     70
# 2    18.0          8           318        150    3436          11.0     70
# 3    16.0          8           304        150    3433          12.0     70
# 4    17.0          8           302        140    3449          10.5     70
# ..    ...        ...           ...        ...     ...           ...    ...
# 193  24.0          6           200         81    3012          17.6     76
# 194  22.5          6           232         90    3085          17.6     76
# 195  29.0          4            85         52    2035          22.2     76
# 196  24.5          4            98         60    2164          22.1     76
# 197  29.0          4            90         70    1937          14.2     76
#
# ...

# %% [markdown]
# ### Step 4. Oops, it seems our first dataset has some unnamed blank columns, fix cars1

# %%
car1=pd.read_csv("cars1.csv")
new_car=car1.drop(["Unnamed: 9","Unnamed: 10","Unnamed: 11","Unnamed: 12","Unnamed: 13"],axis=1)
new_car
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    18.0          8           307        130    3504          12.0     70
# 1    15.0          8           350        165    3693          11.5     70
# 2    18.0          8           318        150    3436          11.0     70
# 3    16.0          8           304        150    3433          12.0     70
# 4    17.0          8           302        140    3449          10.5     70
# ..    ...        ...           ...        ...     ...           ...    ...
# 193  24.0          6           200         81    3012          17.6     76
# 194  22.5          6           232         90    3085          17.6     76
# 195  29.0          4            85         52    2035          22.2     76
# 196  24.5          4            98         60    2164          22.1     76
# 197  29.0          4            90         70    1937          14.2     76
#
#      origin                        car
# ...

# %% [markdown]
# ### Step 5. What is the number of observations in each dataset?

# %% [markdown]
# ### Step 6. Join cars1 and cars2 into a single DataFrame called cars

# %%
cars=pd.concat([df,de],ignore_index=True)
cars
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    18.0          8           307        130    3504          12.0     70
# 1    15.0          8           350        165    3693          11.5     70
# 2    18.0          8           318        150    3436          11.0     70
# 3    16.0          8           304        150    3433          12.0     70
# 4    17.0          8           302        140    3449          10.5     70
# ..    ...        ...           ...        ...     ...           ...    ...
# 393  27.0          4           140         86    2790          15.6     82
# 394  44.0          4            97         52    2130          24.6     82
# 395  32.0          4           135         84    2295          11.6     82
# 396  28.0          4           120         79    2625          18.6     82
# 397  31.0          4           119         82    2720          19.4     82
#
# ...

# %% [markdown]
# ### Step 7. Oops, there is a column missing, called owners. Create a random number Series from 15,000 to 73,000.

# %%
import numpy as np
carr=np.random.randint(15000,73000,size=len(cars))
carr
# Out:
# array([63727, 19786, 15094, 40970, 20267, 21581, 62022, 44299, 68751,
#        36403, 18834, 42112, 42961, 28855, 47717, 21324, 37089, 17270,
#        67058, 41316, 17042, 50543, 50429, 72921, 56286, 22556, 40870,
#        65477, 17045, 65461, 45294, 42821, 53125, 53821, 37119, 45633,
#        32713, 71967, 55883, 43488, 48962, 16001, 59077, 46795, 63417,
#        27540, 65327, 32179, 36769, 49691, 66639, 71629, 59089, 70625,
#        17369, 67664, 36047, 43873, 37785, 62201, 32946, 27232, 71330,
#        45626, 59104, 67893, 63973, 16790, 60775, 56071, 15326, 40830,
#        20001, 29464, 56717, 35114, 31924, 20669, 42075, 22350, 62662,
#        53764, 48337, 21511, 32516, 50985, 72178, 61086, 15512, 34694,
#        62242, 35801, 26050, 33419, 56740, 49285, 16508, 47522, 21630,
#        16236, 21271, 39873, 48640, 43984, 55630, 53150, 71208, 17503,
#        66781, 31949, 47500, 16709, 53656, 50710, 18425, 32459, 65917,
# ...

# %% [markdown]
# ### Step 8. Add the column owners to cars

# %%
cars.insert(0,"owner",[])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 cars.insert(0,"owner",[])
#
# File c:\Users\AKASH\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:5178, in DataFrame.insert(self, loc, column, value, allow_duplicates)
#    5175 elif isinstance(value, DataFrame):
#    5176     value = value.iloc[:, 0]
# -> 5178 value, refs = self._sanitize_column(value)
#    5179 self._mgr.insert(loc, column, value, refs=refs)
#
# File c:\Users\AKASH\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:5273, in DataFrame._sanitize_column(self, value)
#    5270     return _reindex_for_setitem(value, self.index)
#    5272 if is_list_like(value):
# -> 5273     com.require_length_match(value, self.index)
#    5274 arr = sanitize_array(value, self.index, copy=True, allow_2d=True)
#    5275 if (
# ...
